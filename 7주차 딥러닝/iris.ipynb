# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
'''
- 데이터는 총 150개의 로우로 구성되어있으며, 컬럼은 5개가 존재한다.
- 각 컬럼의 결측치는 존재하지 않는다.

- sepal length : 꽃받침의 길이
- sepal width : 꽃받침의 너비
- petal length : 꽃잎의 길이
- petal width : 꽃잎의 너비
- label : 품종
'''
def loadData(name=True):
    iris = load_iris()
    # print(iris.feature_names)
    # print(iris.data)
    # print(iris.target)
    # print(iris.target_names)
    iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
    iris_df['label'] = iris.target
    if(name) :
        iris_df['label'] = iris_df['label'].apply(lambda x: iris.target_names[x])
    # print(iris_df.head())
    return iris_df

# %%
def getOneHotEncodedLabel(y):
    # 문자열을 숫자로 변환
    e = LabelEncoder()
    e.fit(y)
    Y = e.transform(y)
    Y_encoded = tf.keras.utils.to_categorical(Y)
    return Y_encoded

# %%
def eda(df):
    print('-------INFO-------')
    print(df.info())
    # 데이터프레임의 통계 정보
    print('\n-------DESCRIBE-------')
    print(df.describe())
    # label 필드의 고유한 데이터 값
    print('\n-------LABEL UNIQUE-------')
    print(df['label'].unique())
    # iris 데이터의 pairplot
    # sns.pairplot(df, hue='label')

# %%
''' 
결측치 여부 확인
'''
def checkNull(df):
    print('-------- Null Check --------')
    print(df.isnull().sum())

# %%
def dataSplit(df) :
    X = df.iloc[:, :4]
    y = df['label']

    # 학습용 데이터와 테스트용 데이터로 나눔
    X_train, X_test, y_train, y_test = train_test_split(X, y)

    print(len(X_train))
    print(len(X_test))

    return X_train, X_test, y_train, y_test

# %%
def getTreeModel(X_train, y_train):
    # DecisionTreeClassifier 객체 생성
    model = DecisionTreeClassifier(random_state=11)

    # 학습 수행
    model.fit(X_train, y_train)
    return model

# %%
def getBestTreeModel(X_train, y_train):
    dtree = DecisionTreeClassifier()
    parameters = {'max_depth': [1, 2, 3], 'min_samples_split': [2, 3]}

    # param_grid: 하이퍼파라미터
    # cv: 3개의 train, test set fold 로 나누어 학습
    grid_dtree = GridSearchCV(dtree, param_grid=parameters, cv=3)

    # param_grid의 하이퍼파라미터들을 순차적으로 학습
    grid_dtree.fit(X_train, y_train)

    # GridSearchCV 결과 추출하여 DataFrame으로 변환
    scores_df = pd.DataFrame(grid_dtree.cv_results_)
    print(scores_df)
    print(scores_df[['params', 'mean_test_score', 'rank_test_score',
                     'split0_test_score', 'split1_test_score', 'split2_test_score']])
    print('GridSearchCV 최적 파라미터:', grid_dtree.best_params_)
    print('GridSearchCV 최고 정확도: {0:.4f}'.format(grid_dtree.best_score_))

    # 최고 성능을 낸 분류기
    estimator = grid_dtree.best_estimator_
    return estimator

# %%
def printAccuracy(X_test, y_test, model, keras=False):
    model_name = model.__class__.__name__
    if(keras):
        eval = model.evaluate(X_test, getOneHotEncodedLabel(y_test))
        print('{0} 정확도: {1:.4f}, Loss: {2:.4f}'.format(model_name, eval[1], eval[0]))
    else:
        pred = model.predict(X_test)
        print('{0} 정확도: {1:.4f}'.format(model_name, accuracy_score(y_test, pred)))

# %%
def getDenseModel(X_train, y_train):
    # 모델의 설정
    model = Sequential()
    model.add(Dense(16,  input_dim=4, activation='relu'))
    model.add(Dense(3, activation='softmax'))

    # 모델 컴파일
    model.compile(loss='categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])

    # 모델 실행
    model.fit(X_train, y_train, epochs=50, batch_size=1)

    return model

# %%
if __name__ == "__main__":
    df = loadData(False)
    eda(df)
    checkNull(df)
    X_train, X_test, y_train, y_test = dataSplit(df)
    model = getTreeModel(X_train, y_train)
    printAccuracy(X_test, y_test, model)
    
    model = getBestTreeModel(X_train, y_train)
    printAccuracy(X_test, y_test, model)

    df = loadData(True)
    X_train, X_test, y_train, y_test = dataSplit(df)
    model = getDenseModel(X_train, getOneHotEncodedLabel(y_train))
    model.summary()
    printAccuracy(X_test, y_test, model, True)
# Out:
# -------INFO-------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   label              150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
#
# -------DESCRIBE-------
#        sepal length (cm)  sepal width (cm)  ...  petal width (cm)       label
# count         150.000000        150.000000  ...        150.000000  150.000000
# mean            5.843333          3.057333  ...          1.199333    1.000000
# std             0.828066          0.435866  ...          0.762238    0.819232
# min             4.300000          2.000000  ...          0.100000    0.000000
# 25%             5.100000          2.800000  ...          0.300000    0.000000
# 50%             5.800000          3.000000  ...          1.300000    1.000000
# 75%             6.400000          3.300000  ...          1.800000    2.000000
# max             7.900000          4.400000  ...          2.500000    2.000000
#
# [8 rows x 5 columns]
#
# -------LABEL UNIQUE-------
# [0 1 2]
# -------- Null Check --------
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# label                0
# dtype: int64
# 112
# 38
# DecisionTreeClassifier 정확도: 0.9737
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.001191      0.000124  ...        0.004023                5
# 1       0.001087      0.000003  ...        0.004023                5
# 2       0.001107      0.000018  ...        0.022090                3
# 3       0.001093      0.000001  ...        0.022090                3
# 4       0.001098      0.000003  ...        0.012269                1
# 5       0.001110      0.000006  ...        0.012269                1
#
# [6 rows x 13 columns]
#                                      params  ...  split2_test_score
# 0  {'max_depth': 1, 'min_samples_split': 2}  ...           0.675676
# 1  {'max_depth': 1, 'min_samples_split': 3}  ...           0.675676
# 2  {'max_depth': 2, 'min_samples_split': 2}  ...           0.945946
# 3  {'max_depth': 2, 'min_samples_split': 3}  ...           0.945946
# 4  {'max_depth': 3, 'min_samples_split': 2}  ...           0.918919
# 5  {'max_depth': 3, 'min_samples_split': 3}  ...           0.918919
#
# [6 rows x 6 columns]
# GridSearchCV 최적 파라미터: {'max_depth': 3, 'min_samples_split': 2}
# GridSearchCV 최고 정확도: 0.9286
# DecisionTreeClassifier 정확도: 0.9474
# 112
# 38
# Epoch 1/50
# 112/112 [==============================] - 0s 2ms/step - loss: 1.2116 - accuracy: 0.3393
# Epoch 2/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.8058 - accuracy: 0.6518
# Epoch 3/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.6551 - accuracy: 0.7143
# Epoch 4/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.5810 - accuracy: 0.7857
# Epoch 5/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.5331 - accuracy: 0.7768
# Epoch 6/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4813 - accuracy: 0.7946
# Epoch 7/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4533 - accuracy: 0.8214
# Epoch 8/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4313 - accuracy: 0.8304
# Epoch 9/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.3972 - accuracy: 0.8839
# Epoch 10/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.9107
# Epoch 11/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.3646 - accuracy: 0.8929
# Epoch 12/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.9018
# Epoch 13/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.3264 - accuracy: 0.9375
# Epoch 14/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.3093 - accuracy: 0.9643
# Epoch 15/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.9375
# Epoch 16/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.3028 - accuracy: 0.9554
# Epoch 17/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2715 - accuracy: 0.9643
# Epoch 18/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.9643
# Epoch 19/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.9643
# Epoch 20/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2237 - accuracy: 0.9643
# Epoch 21/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.9643
# Epoch 22/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.9643
# Epoch 23/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2074 - accuracy: 0.9821
# Epoch 24/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.2029 - accuracy: 0.9643
# Epoch 25/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1881 - accuracy: 0.9732
# Epoch 26/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1873 - accuracy: 0.9732
# Epoch 27/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1762 - accuracy: 0.9732
# Epoch 28/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1656 - accuracy: 0.9821
# Epoch 29/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9732
# Epoch 30/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1556 - accuracy: 0.9821
# Epoch 31/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1578 - accuracy: 0.9643
# Epoch 32/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1453 - accuracy: 0.9821
# Epoch 33/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1416 - accuracy: 0.9821
# Epoch 34/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1414 - accuracy: 0.9643
# Epoch 35/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1325 - accuracy: 0.9821
# Epoch 36/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1275 - accuracy: 0.9821
# Epoch 37/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1299 - accuracy: 0.9821
# Epoch 38/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1267 - accuracy: 0.9643
# Epoch 39/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1200 - accuracy: 0.9911
# Epoch 40/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1131 - accuracy: 0.9821
# Epoch 41/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1161 - accuracy: 0.9821
# Epoch 42/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 0.9821
# Epoch 43/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1085 - accuracy: 0.9821
# Epoch 44/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.9821
# Epoch 45/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 0.9911
# Epoch 46/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.9643
# Epoch 47/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.0929 - accuracy: 0.9732
# Epoch 48/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9732
# Epoch 49/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.0963 - accuracy: 0.9911
# Epoch 50/50
# 112/112 [==============================] - 0s 2ms/step - loss: 0.0896 - accuracy: 0.9821
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 16)                80
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1908 - accuracy: 0.9211
# Sequential 정확도: 0.9211, Loss: 0.1908

# %%
# !nvidia-smi
# Out:
# Mon Oct 26 02:17:12 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P0    31W /  70W |    289MiB / 15079MiB |      9%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
