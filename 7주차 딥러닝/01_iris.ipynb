# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV


'''
- 데이터는 총 150개의 로우로 구성되어있으며, 컬럼은 5개가 존재한다.
- 각 컬럼의 결측치는 존재하지 않는다.

- sepal length : 꽃받침의 길이
- sepal width : 꽃받침의 너비
- petal length : 꽃잎의 길이
- petal width : 꽃잎의 너비
- label : 품종
'''
def loadData(name=True):
    iris = load_iris()
    # print(iris.feature_names)
    # print(iris.data)
    # print(iris.target)
    # print(iris.target_names)
    iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
    iris_df['label'] = iris.target
    if(name) :
        iris_df['label'] = iris_df['label'].apply(lambda x: iris.target_names[x])
    # print(iris_df.head())
    return iris_df


def getOneHotEncodedLabel(y):
    # 문자열을 숫자로 변환
    e = LabelEncoder()
    e.fit(y)
    Y = e.transform(y)
    Y_encoded = tf.keras.utils.to_categorical(Y)
    return Y_encoded

def eda(df):
    print('-------INFO-------')
    print(df.info())
    # 데이터프레임의 통계 정보
    print('\n-------DESCRIBE-------')
    print(df.describe())
    # label 필드의 고유한 데이터 값
    print('\n-------LABEL UNIQUE-------')
    print(df['label'].unique())
    # iris 데이터의 pairplot
    # sns.pairplot(df, hue='label')

''' 
결측치 여부 확인
'''
def checkNull(df):
    print('-------- Null Check --------')
    print(df.isnull().sum())

def dataSplit(df) :
    X = df.iloc[:, :4]
    y = df['label']

    # 학습용 데이터와 테스트용 데이터로 나눔
    X_train, X_test, y_train, y_test = train_test_split(X, y)

    print(len(X_train))
    print(len(X_test))

    return X_train, X_test, y_train, y_test

def getTreeModel(X_train, y_train):
    # DecisionTreeClassifier 객체 생성
    model = DecisionTreeClassifier(random_state=11)

    # 학습 수행
    model.fit(X_train, y_train)
    return model

def getBestTreeModel(X_train, y_train):
    dtree = DecisionTreeClassifier()
    parameters = {'max_depth': [1, 2, 3], 'min_samples_split': [2, 3]}

    # param_grid: 하이퍼파라미터
    # cv: 3개의 train, test set fold 로 나누어 학습
    grid_dtree = GridSearchCV(dtree, param_grid=parameters, cv=3)

    # param_grid의 하이퍼파라미터들을 순차적으로 학습
    grid_dtree.fit(X_train, y_train)

    # GridSearchCV 결과 추출하여 DataFrame으로 변환
    scores_df = pd.DataFrame(grid_dtree.cv_results_)
    print(scores_df)
    print(scores_df[['params', 'mean_test_score', 'rank_test_score',
                     'split0_test_score', 'split1_test_score', 'split2_test_score']])
    print('GridSearchCV 최적 파라미터:', grid_dtree.best_params_)
    print('GridSearchCV 최고 정확도: {0:.4f}'.format(grid_dtree.best_score_))

    # 최고 성능을 낸 분류기
    estimator = grid_dtree.best_estimator_
    return estimator

def printAccuracy(X_test, y_test, model, keras=False):
    model_name = model.__class__.__name__
    if(keras):
        eval = model.evaluate(X_test, getOneHotEncodedLabel(y_test))
        print('{0} 정확도: {1:.4f}, Loss: {2:.4f}'.format(model_name, eval[1], eval[0]))
    else:
        pred = model.predict(X_test)
        print('{0} 정확도: {1:.4f}'.format(model_name, accuracy_score(y_test, pred)))

def getDenseModel(X_train, y_train):
    # 모델의 설정
    model = Sequential()
    model.add(Dense(16,  input_dim=4, activation='relu'))
    model.add(Dense(3, activation='softmax'))

    # 모델 컴파일
    model.compile(loss='categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])

    # 모델 실행
    model.fit(X_train, y_train, epochs=50, batch_size=1)

    return model

if __name__ == "__main__":
    df = loadData(False)
    eda(df)
    checkNull(df)
    X_train, X_test, y_train, y_test = dataSplit(df)
    model = getTreeModel(X_train, y_train)
    printAccuracy(X_test, y_test, model)

    df = loadData(True)
    X_train, X_test, y_train, y_test = dataSplit(df)
    model = getDenseModel(X_train, getOneHotEncodedLabel(y_train))
    model.summary()
    printAccuracy(X_test, y_test, model, True)
# Out:
# -------INFO-------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   label              150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB
# None
#
# -------DESCRIBE-------
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)       label
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000
#
# -------LABEL UNIQUE-------
# [0 1 2]
# -------- Null Check --------
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# label                0
# dtype: int64
# 112
# 38
# DecisionTreeClassifier 정확도: 1.0000
# 112
# 38
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 112 samples
# Epoch 1/50
# 112/112 [==============================] - 0s 3ms/sample - loss: 2.5458 - accuracy: 0.3750
# Epoch 2/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.9668 - accuracy: 0.6250
# Epoch 3/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.6963 - accuracy: 0.7589
# Epoch 4/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.6026 - accuracy: 0.7768
# Epoch 5/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.5502 - accuracy: 0.8571
# Epoch 6/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.5083 - accuracy: 0.9018
# Epoch 7/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4720 - accuracy: 0.9018
# Epoch 8/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4448 - accuracy: 0.9018
# Epoch 9/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.4170 - accuracy: 0.9286
# Epoch 10/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3986 - accuracy: 0.9554
# Epoch 11/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3764 - accuracy: 0.9554
# Epoch 12/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3573 - accuracy: 0.9286
# Epoch 13/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3392 - accuracy: 0.9375
# Epoch 14/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3225 - accuracy: 0.9643
# Epoch 15/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.3087 - accuracy: 0.9643
# Epoch 16/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2890 - accuracy: 0.9643
# Epoch 17/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2772 - accuracy: 0.9732
# Epoch 18/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2632 - accuracy: 0.9821
# Epoch 19/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2506 - accuracy: 0.9732
# Epoch 20/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2439 - accuracy: 0.9464
# Epoch 21/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2306 - accuracy: 0.9643
# Epoch 22/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2202 - accuracy: 0.9732
# Epoch 23/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2141 - accuracy: 0.9732
# Epoch 24/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.2050 - accuracy: 0.9554
# Epoch 25/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1932 - accuracy: 0.9732
# Epoch 26/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1895 - accuracy: 0.9643
# Epoch 27/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1849 - accuracy: 0.9732
# Epoch 28/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1786 - accuracy: 0.9643
# Epoch 29/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1725 - accuracy: 0.9643
# Epoch 30/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1666 - accuracy: 0.9821
# Epoch 31/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1585 - accuracy: 0.9732
# Epoch 32/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1560 - accuracy: 0.9732
# Epoch 33/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1490 - accuracy: 0.9732
# Epoch 34/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1432 - accuracy: 0.9732
# Epoch 35/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1379 - accuracy: 0.9732
# Epoch 36/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1409 - accuracy: 0.9821
# Epoch 37/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1351 - accuracy: 0.9821
# Epoch 38/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1371 - accuracy: 0.9643
# Epoch 39/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1260 - accuracy: 0.9732
# Epoch 40/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1250 - accuracy: 0.9732
# Epoch 41/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1164 - accuracy: 0.9732
# Epoch 42/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1210 - accuracy: 0.9821
# Epoch 43/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1216 - accuracy: 0.9554
# Epoch 44/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1149 - accuracy: 0.9732
# Epoch 45/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1095 - accuracy: 0.9821
# Epoch 46/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1186 - accuracy: 0.9732
# Epoch 47/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1231 - accuracy: 0.9554
# Epoch 48/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1028 - accuracy: 0.9821
# Epoch 49/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1081 - accuracy: 0.9643
# Epoch 50/50
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.1003 - accuracy: 0.9821
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                80
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 38/38 [==============================] - 0s 893us/sample - loss: 0.1649 - accuracy: 0.9211
# Sequential 정확도: 0.9211, Loss: 0.1649
